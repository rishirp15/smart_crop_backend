# %% [markdown]
# # this is for converting the soil classifier TFjs model into a local keras model and not a browser one

# %%
# !rm -rf Pixsoil
# !git clone https://github.com/EricEchemane/Pixsoil.git

# %pip install tensorflowjs tensorflow

# clean output
# !rm -rf ./soil_model/

# convert model
# !tensorflowjs_converter \
    --input_format=tfjs_layers_model \
    --output_format=keras_saved_model \
    Pixsoil/public/tfjs_files/model.json \
    ./soil_model/

# check output
# !ls -R ./soil_model/
# Out:
# Cloning into 'Pixsoil'...
# remote: Enumerating objects: 628, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 628 (delta 40), reused 42 (delta 22), pack-reused 558 (from 1)
# Receiving objects: 100% (628/628), 127.79 MiB | 35.04 MiB/s, done.
# Resolving deltas: 100% (371/371), done.
# ...
# 2026-03-05 04:53:43.491001: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772686423.521829    3201 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
import tensorflow as tf
import numpy as np

m = tf.saved_model.load("./soil_model")

# Correct the dummy input shape to (1, 256, 256, 3) as expected by the model
dummy = tf.constant(np.zeros((1,256,256,3), dtype=np.float32))

out = list(m.signatures["serving_default"](dummy).values())[0]

print(out.shape)
# Out:
# (1, 11)

# %%
# !zip -r soil_model.zip ./soil_model
# Out:
#   adding: soil_model/ (stored 0%)
#   adding: soil_model/fingerprint.pb (stored 0%)
#   adding: soil_model/keras_metadata.pb (deflated 94%)
#   adding: soil_model/variables/ (stored 0%)
#   adding: soil_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: soil_model/variables/variables.index (deflated 62%)
#   adding: soil_model/assets/ (stored 0%)
#   adding: soil_model/saved_model.pb (deflated 90%)
